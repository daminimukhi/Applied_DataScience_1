# %%
# installing the libraries 
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# !pip install sklearn

# %%
# import numpy, pandas , matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IMPORT CSV FILE
dataset = pd.read_csv('mental_health_data.csv')

# %%
dataset
# Out:
#                       Timestamp                         Username  Age  Gender  \
# 0     2022/09/03 6:44:25 PM GMT        komaldeepani510@gmail.com   17  Female
# 1     2022/09/03 6:46:07 PM GMT    bakhtawarsolangi786@gmail.com   22  Female
# 2     2022/09/03 6:48:31 PM GMT         rakhi.lohana12@yahoo.com   18  Female
# 3     2022/09/03 6:48:34 PM GMT       aliahmedwarrior0@gmail.com   23    Male
# 4     2022/09/03 6:49:45 PM GMT           krishkumar99@gmail.com   16    Male
# ..                          ...                              ...  ...     ...
# 315  2022/10/06 10:27:27 PM GMT          mfaisal.yamin@gmail.com   24    Male
# 316   2022/10/07 7:15:08 PM GMT            katiarrubab@gmail.com   18  Female
# 317   2022/10/23 8:51:31 AM GMT              aa4571756@gmail.com   21    Male
# 318   2023/06/06 4:24:47 AM GMT  iqrajamaliiqrajamali3@gmail.com   18  Female
# 319   2023/06/18 4:47:04 PM GMT             khanwandbux@gmil.com   15    Male
#
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Understanding the dataset
dataset.head()
# Out:
#                    Timestamp                       Username  Age  Gender  \
# 0  2022/09/03 6:44:25 PM GMT      komaldeepani510@gmail.com   17  Female
# 1  2022/09/03 6:46:07 PM GMT  bakhtawarsolangi786@gmail.com   22  Female
# 2  2022/09/03 6:48:31 PM GMT       rakhi.lohana12@yahoo.com   18  Female
# 3  2022/09/03 6:48:34 PM GMT     aliahmedwarrior0@gmail.com   23    Male
# 4  2022/09/03 6:49:45 PM GMT         krishkumar99@gmail.com   16    Male
#
#     Country            State       You Are ?  \
# 0  Pakistan         Pakistan  I am a Student
# 1  Pakistan          Karachi  I am a Student
# 2  Pakistan           Single  I am a Student
# 3  Pakistan        Hyderabad  I am a Student
# 4  Pakistan  Getting torched  I am a Student
#
#   Do you have a family history of mental illness? Any Treatment ?  \
# 0                                              No             Yes
# 1                                              No              No
# ...

# %%
dataset.tail()
# Out:
#                       Timestamp                         Username  Age  Gender  \
# 315  2022/10/06 10:27:27 PM GMT          mfaisal.yamin@gmail.com   24    Male
# 316   2022/10/07 7:15:08 PM GMT            katiarrubab@gmail.com   18  Female
# 317   2022/10/23 8:51:31 AM GMT              aa4571756@gmail.com   21    Male
# 318   2023/06/06 4:24:47 AM GMT  iqrajamaliiqrajamali3@gmail.com   18  Female
# 319   2023/06/18 4:47:04 PM GMT             khanwandbux@gmil.com   15    Male
#
#       Country    State       You Are ?  \
# 315  Pakistan    Sindh  I am a Student
# 316  Pakistan    Sindh  I am a Student
# 317  Pakistan    Sindh  I am a Student
# 318  Pakistan     Yes   I am a Student
# 319  Pakistan  student  I am a Student
#
#     Do you have a family history of mental illness? Any Treatment ?  \
# 315                                              No              No
# 316                                              No              No
# ...

# %%
dataset.shape
# Out:
# (320, 16)

# %%
print('Number of Columns',dataset.shape[0])
print('Number of Rows',dataset.shape[1])
# Out:
# Number of Columns 320
# Number of Rows 16

# %%
dataset.isnull().sum()
# Out:
# Timestamp                                                                                                       0
# Username                                                                                                        0
# Age                                                                                                             0
# Gender                                                                                                          0
# Country                                                                                                         0
# State                                                                                                           1
# You Are ?                                                                                                       0
# Do you have a family history of mental illness?                                                                 0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 16 columns):
#  #   Column                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                      --------------  -----
#  0   Timestamp                                                                                                   320 non-null    object
#  1   Username                                                                                                    320 non-null    object
#  2   Age                                                                                                         320 non-null    int64
#  3   Gender                                                                                                      320 non-null    object
# ...

# %%
dataset.describe()
# Out:
#               Age
# count  320.000000
# mean    22.437500
# std      5.284018
# min     14.000000
# 25%     20.000000
# 50%     22.000000
# 75%     23.000000
# max     60.000000

# %%
dataset.corr
# Out:
# <bound method DataFrame.corr of                       Timestamp                         Username  Age  Gender  \
# 0     2022/09/03 6:44:25 PM GMT        komaldeepani510@gmail.com   17  Female
# 1     2022/09/03 6:46:07 PM GMT    bakhtawarsolangi786@gmail.com   22  Female
# 2     2022/09/03 6:48:31 PM GMT         rakhi.lohana12@yahoo.com   18  Female
# 3     2022/09/03 6:48:34 PM GMT       aliahmedwarrior0@gmail.com   23    Male
# 4     2022/09/03 6:49:45 PM GMT           krishkumar99@gmail.com   16    Male
# ..                          ...                              ...  ...     ...
# 315  2022/10/06 10:27:27 PM GMT          mfaisal.yamin@gmail.com   24    Male
# 316   2022/10/07 7:15:08 PM GMT            katiarrubab@gmail.com   18  Female
# 317   2022/10/23 8:51:31 AM GMT              aa4571756@gmail.com   21    Male
# 318   2023/06/06 4:24:47 AM GMT  iqrajamaliiqrajamali3@gmail.com   18  Female
# 319   2023/06/18 4:47:04 PM GMT             khanwandbux@gmil.com   15    Male
#
# ...

# %%
cat = []
num = []
for column in data.columns:
    if data[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
num
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized',
#  'Eating disorders (share of population) - Sex: Both - Age: Age-standardized']

# %%
cat
# Out:
# []

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'Username', 'Age', 'Gender', 'Country', 'State',
#        'You Are ?', 'Do you have a family history of mental illness?',
#        'Any Treatment ?',
#        'If you have a mental health condition, do you feel that it interferes with your work?',
#        'Over the last 2 weeks, how often have you been feeling nervous or anxious?',
#        'how often have you been bothered by not being able to control your thoughts or worries? in front of people',
#        'how often have you felt little interest or pleasure in doing things that you normally enjoyed doing?',
#        'how often have you felt down, depressed, or hopeless?',
#        'Have you ever experienced an attack of fear, anxiety, or panic?',
#        'Why you have experienced an attack of fear, anxiety, or panic ? (if not then type NA)'],
#       dtype='object')

# %%
dataset.nunique()
# Out:
# Timestamp                                                                                                     320
# Username                                                                                                      319
# Age                                                                                                            26
# Gender                                                                                                          3
# Country                                                                                                         5
# State                                                                                                          71
# You Are ?                                                                                                       5
# Do you have a family history of mental illness?                                                                 2
# ...

# %%
sns.countplot(x='Gender', data=dataset, palette=['Pink', 'skyBlue','Blue'])
plt.show()

# %%
dataset['Gender'].value_counts()
# Out:
# Gender
# Male                 186
# Female               133
# Prefer not to say      1
# Name: count, dtype: int64

# %%
dataset['Gender'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
dataset['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Prefer not to say'], dtype=object)

# %%
# Histogram of Gender
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Gender'], bins=20, kde=True, color='brown')
plt.show()

# %%
dataset['Age'].unique()
# Out:
# array([17, 22, 18, 23, 16, 20, 19, 21, 49, 46, 29, 27, 25, 24, 35, 32, 28,
#        37, 26, 14, 60, 48, 30, 44, 55, 15], dtype=int64)

# %%
# Histogram of Age
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Age'], bins=20, kde=True, color='purple')
plt.show()

# %%
dataset['Age'].value_counts()
# Out:
# Age
# 22    70
# 21    57
# 23    36
# 20    34
# 18    31
# 19    19
# 24    14
# 25    13
# 27    11
# 17     5
# 28     4
# 26     4
# 46     3
# 16     3
# 32     3
# 29     2
# 30     2
# 49     1
# 35     1
# 37     1
# 14     1
# 60     1
# 48     1
# 44     1
# 55     1
# 15     1
# Name: count, dtype: int64

# %%
dataset['Age'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of County
plt.figure(figsize=(8, 6))
sns.histplot(dataset['Country'], bins=20, kde=True, color='purple')
plt.show()

# %%
dataset['Country'].value_counts()
# Out:
# Country
# Pakistan        315
# India             2
# Australia         1
# Canada            1
# Saudi Arabia      1
# Name: count, dtype: int64

# %%
dataset['Country'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
dataset['You Are ?'].unique()
# Out:
# array(['I am a Student', 'I am a Business Man/Woman', 'I am an Employee',
#        'I am a House Wife/Husband', 'I am an Entrepreneur'], dtype=object)

# %%
# Histogram of profession
plt.figure(figsize=(20, 6))
sns.histplot(dataset['You Are ?'], bins=20, kde=True, color='skyblue')
plt.show()

# %%
dataset['You Are ?'].value_counts()
# Out:
# You Are ?
# I am a Student               248
# I am an Employee              39
# I am a Business Man/Woman     16
# I am a House Wife/Husband     10
# I am an Entrepreneur           7
# Name: count, dtype: int64

# %%
dataset['You Are ?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
dataset['Do you have a family history of mental illness?'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dataset['Do you have a family history of mental illness?'].value_counts()
# Out:
# Do you have a family history of mental illness?
# No     274
# Yes     46
# Name: count, dtype: int64

# %%
dataset['Do you have a family history of mental illness?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of Family history
plt.figure(figsize=(20, 6))
sns.histplot(dataset['Do you have a family history of mental illness?'], bins=20, kde=True, color='green')
plt.show()

# %%
dataset['Any Treatment ?'].value_counts()
# Out:
# Any Treatment ?
# No     226
# Yes     32
# Name: count, dtype: int64

# %%
dataset['Any Treatment ?'].value_counts().plot(kind='pie', autopct="%1.2f%%")

# %%
# Histogram of Treatement
plt.figure(figsize=(20, 6))
sns.histplot(dataset['Any Treatment ?'], bins=20, kde=True, color='orange')
plt.show()

# %%
dataset['If you have a mental health condition, do you feel that it interferes with your work?'].value_counts()
# Out:
# If you have a mental health condition, do you feel that it interferes with your work?
# Sometimes       79
# Never           69
# Often           31
# Always          30
# Occasionally    27
# Name: count, dtype: int64

# %%
dataset['If you have a mental health condition, do you feel that it interferes with your work?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of Interference in work
plt.figure(figsize=(20, 6))
sns.histplot(dataset['If you have a mental health condition, do you feel that it interferes with your work?'], bins=20, kde=True, color='orange')
plt.show()

# %%
dataset['Over the last 2 weeks, how often have you been feeling nervous or anxious?'].value_counts()
# Out:
# Over the last 2 weeks, how often have you been feeling nervous or anxious?
# A few days but less than a week    125
# Not at all                         116
# Every single day                    33
# More than a week                    26
# More than two weeks                 20
# Name: count, dtype: int64

# %%
dataset['Over the last 2 weeks, how often have you been feeling nervous or anxious?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of how often have you been feeling nervous
plt.figure(figsize=(20, 6))
sns.histplot(dataset['Over the last 2 weeks, how often have you been feeling nervous or anxious?'], bins=20, kde=True, color='yellow')
plt.show()

# %%
dataset['how often have you been bothered by not being able to control your thoughts or worries? in front of people'].value_counts()
# Out:
# how often have you been bothered by not being able to control your thoughts or worries? in front of people
# Rarely in a month     164
# Some Day in a week     83
# Everyday               50
# Every next day         23
# Name: count, dtype: int64

# %%
dataset['how often have you been bothered by not being able to control your thoughts or worries? in front of people'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of how often have you been bothered
plt.figure(figsize=(20, 6))
sns.histplot(dataset['how often have you been bothered by not being able to control your thoughts or worries? in front of people'], bins=20, kde=True, color='coral')
plt.show()

# %%
dataset['how often have you felt little interest or pleasure in doing things that you normally enjoyed doing?'].value_counts()
# Out:
# how often have you felt little interest or pleasure in doing things that you normally enjoyed doing?
# Some Day in a week    136
# Rarely in a month      78
# Everyday               66
# Every next day         40
# Name: count, dtype: int64

# %%
dataset['how often have you felt little interest or pleasure in doing things that you normally enjoyed doing?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of how often have you felt little interest or pleasure in doing things
plt.figure(figsize=(20, 6))
sns.histplot(dataset['how often have you felt little interest or pleasure in doing things that you normally enjoyed doing?'], bins=20, kde=True, color='turquoise')
plt.show()

# %%
dataset['how often have you felt down, depressed, or hopeless?'].value_counts()
# Out:
# how often have you felt down, depressed, or hopeless?
# Rarely in a month     128
# Some Day in a week    110
# Every next day         42
# Everyday               40
# Name: count, dtype: int64

# %%
dataset['how often have you felt down, depressed, or hopeless?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of how often have you felt down
plt.figure(figsize=(20, 6))
sns.histplot(dataset['how often have you felt down, depressed, or hopeless?'], bins=20, kde=True, color='teal')
plt.show()

# %%
dataset["Have you ever experienced an attack of fear, anxiety, or panic?"].value_counts()
# Out:
# Have you ever experienced an attack of fear, anxiety, or panic?
# No       154
# Yes      111
# Maybe     55
# Name: count, dtype: int64

# %%
dataset['Have you ever experienced an attack of fear, anxiety, or panic?'].value_counts().plot(kind='pie', autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram of Have you ever experienced any attack
plt.figure(figsize=(20, 6))
sns.histplot(dataset['Have you ever experienced an attack of fear, anxiety, or panic?'], bins=20, kde=True, color='coral')
plt.show()

# %%
dataset['Why you have experienced an attack of fear, anxiety, or panic ? (if not then type NA)'].value_counts()
# Out:
# Why you have experienced an attack of fear, anxiety, or panic ? (if not then type NA)
# Na                                                                                                23
# No                                                                                                 9
# NA                                                                                                 3
# .                                                                                                  3
# Yes                                                                                                3
#                                                                                                   ..
# Our country's law and order and climate changes in our country                                     1
# Anxiety attacks are often happening.                                                               1
# ...

# %%
sns.scatterplot(x='Age', y='Gender', data=dataset)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='Country', y='You Are ?', data=dataset, color='')
# Out:
# <Axes: xlabel='Country', ylabel='You Are ?'>

# %%
sns.histplot(x='Do you have a family history of mental illness?', y='Any Treatment ?', data=dataset)
# Out:
# <Axes: xlabel='Do you have a family history of mental illness?', ylabel='Any Treatment ?'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='Gender', y='how often have you been bothered by not being able to control your thoughts or worries? in front of people', data=dataset, color='brown')
# Out:
# <Axes: xlabel='Gender', ylabel='how often have you been bothered by not being able to control your thoughts or worries? in front of people'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='how often have you felt down, depressed, or hopeless?', y='Have you ever experienced an attack of fear, anxiety, or panic?', data=dataset, color='darkgreen')
# Out:
# <Axes: xlabel='how often have you felt down, depressed, or hopeless?', ylabel='Have you ever experienced an attack of fear, anxiety, or panic?'>
